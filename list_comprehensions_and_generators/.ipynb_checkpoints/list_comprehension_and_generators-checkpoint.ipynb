# %% [markdown]
# List Comprehensions and Generators

# %%
# Step 1: import modules
from collections import Counter
import calendar
import itertools
import random
import re
import requests
import string

# %% [markdown]
# List Comprehensions

# %%
names = 'pybites matt bob julian sam'.split()
names
# Out:
# ['pybites', 'matt', 'bob', 'julian', 'sam']

# %%
# title case each name from the list
for name in names: print(name.title())
# Out:
# Pybites
# Matt
# Bob
# Julian
# Sam

# %%
# now I only want to look at names that start with A-M, Python's string library makes that pretty simple to do
first_half_alphabet = list(string.ascii_lowercase)[:13]
first_half_alphabet
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm']

# %%
new_names = []
for name in names:
    if name[0] in first_half_alphabet:
        new_names.append(name.title())
new_names
# Out:
# ['Matt', 'Bob', 'Julian']

# %%
# same thing as the previous cell but this is more pythonic since it is all in one line
new_names2 = [name.title() for name in names if name[0] in first_half_alphabet]
new_names2
# Out:
# ['Matt', 'Bob', 'Julian']

# %% [markdown]
# This is the portion of the notebook where we can clean up words in lists using list comprehensions

# %%
resp = requests.get('http://projects.bobbelderbos.com/pcc/harry.txt')
words = resp.text.lower().split()
words[:5]
# Out:
# ['the', 'boy', 'who', 'lived', 'mr.']

# %% [markdown]
# Now to get the most common words.

# %%
cnt = Counter(words)
cnt.most_common(5)
# Out:
# [('the', 202), ('he', 136), ('a', 108), ('and', 100), ('to', 93)]

# %% [markdown]
# If you notice from the previous part, there are non alphabetical characters that got counted as well in the list so let's get rid of those

# %%
# \W matches any non alphanumeric characters
words = [re.sub(r'\W+', r'', word) for word in words]

# %% [markdown]
# Now verify that words were maintain but extraneous characters were removed.

# %%
'_' in words
# Out:
# False

# %%
'the' in words
# Out:
# True

# %% [markdown]
# Now, let's try this again and try to lessen the amount of cells required for this excercise.

# %%
resp = requests.get('http://projects.bobbelderbos.com/pcc/stopwords.txt')
stopwords = resp.text.lower().split()
len(stopwords)
# Out:
# 319

# %%
words = [word for word in words if word.strip() and word not in stopwords]
words
# fun fact discovered by accident, turns out, python is very forgiving since I fogot the parentheses after the strip method 
# and it still ran correctly. who knew?
# Out:
# ['boy',
#  'lived',
#  'mr',
#  'mrs',
#  'dursley',
#  'number',
#  'privet',
#  'drive',
#  'proud',
#  'say',
#  'perfectly',
#  'normal',
#  'thank',
#  'people',
#  'youd',
#  'expect',
#  'involved',
#  'strange',
#  'mysterious',
#  'just',
#  'didnt',
#  'hold',
#  'nonsense',
#  'mr',
#  'dursley',
#  'director',
#  'firm',
#  'called',
#  'grunnings',
#  'drills',
#  'big',
#  'beefy',
#  'man',
#  'hardly',
#  'neck',
#  'did',
#  'large',
#  'mustache',
#  'mrs',
#  'dursley',
#  'blonde',
#  'nearly',
#  'twice',
#  'usual',
#  'neck',
#  'came',
#  'useful',
#  'spent',
#  'time',
#  'craning',
#  'garden',
#  'fences',
#  'spying',
#  'neighbors',
#  'dursleys',
#  'small',
#  'son',
#  'called',
#  'dudley',
#  'opinion',
#  'finer',
#  'boy',
#  'dursleys',
#  'wanted',
#  'secret',
#  'greatest',
#  'fear',
#  'somebody',
#  'discover',
#  'didnt',
#  'think',
#  'bear',
#  'potters',
#  'mrs',
#  'potter',
#  'mrs',
#  'dursleys',
#  'sister',
#  'hadnt',
#  'met',
#  'years',
#  'fact',
#  'mrs',
#  'dursley',
#  'pretended',
#  'didnt',
#  'sister',
#  'sister',
#  'goodfornothing',
#  'husband',
#  'undursleyish',
#  'possible',
#  'dursleys',
#  'shuddered',
#  'think',
#  'neighbors',
#  'say',
#  'potters',
#  'arrived',
#  'street',
#  'dursleys',
#  'knew',
#  'potters',
#  'small',
#  'son',
#  'seen',
#  'boy',
#  'good',
#  'reason',
#  'keeping',
#  'potters',
#  'away',
#  'didnt',
#  'want',
#  'dudley',
#  'mixing',
#  'child',
#  'like',
#  'mr',
#  'mrs',
#  'dursley',
#  'woke',
#  'dull',
#  'gray',
#  'tuesday',
#  'story',
#  'starts',
#  'cloudy',
#  'sky',
#  'outside',
#  'suggest',
#  'strange',
#  'mysterious',
#  'things',
#  'soon',
#  'happening',
#  'country',
#  'mr',
#  'dursley',
#  'hummed',
#  'picked',
#  'boring',
#  'tie',
#  'work',
#  'mrs',
#  'dursley',
#  'gossiped',
#  'away',
#  'happily',
#  'wrestled',
#  'screaming',
#  'dudley',
#  'high',
#  'chair',
#  'noticed',
#  'large',
#  'tawny',
#  'owl',
#  'flutter',
#  'past',
#  'window',
#  'half',
#  'past',
#  'mr',
#  'dursley',
#  'picked',
#  'briefcase',
#  'pecked',
#  'mrs',
#  'dursley',
#  'cheek',
#  'tried',
#  'kiss',
#  'dudley',
#  'goodbye',
#  'missed',
#  'dudley',
#  'having',
#  'tantrum',
#  'throwing',
#  'cereal',
#  'walls',
#  'little',
#  'tyke',
#  'chortled',
#  'mr',
#  'dursley',
#  'left',
#  'house',
#  'got',
#  'car',
#  'backed',
#  'number',
#  'fours',
#  'drive',
#  'corner',
#  'street',
#  'noticed',
#  'sign',
#  'peculiar',
#  'cat',
#  'reading',
#  'map',
#  'second',
#  'mr',
#  'dursley',
#  'didnt',
#  'realize',
#  'seen',
#  'jerked',
#  'head',
#  'look',
#  'tabby',
#  'cat',
#  'standing',
#  'corner',
#  'privet',
#  'drive',
#  'wasnt',
#  'map',
#  'sight',
#  'thinking',
#  'trick',
#  'light',
#  'mr',
#  'dursley',
#  'blinked',
#  'stared',
#  'cat',
#  'stared',
#  'mr',
#  'dursley',
#  'drove',
#  'corner',
#  'road',
#  'watched',
#  'cat',
#  'mirror',
#  'reading',
#  'sign',
#  'said',
#  'privet',
#  'drive',
#  'looking',
#  'sign',
#  'cats',
#  'read',
#  'maps',
#  'signs',
#  'mr',
#  'dursley',
#  'gave',
#  'himself',
#  'little',
#  'shake',
#  'cat',
#  'mind',
#  'drove',
#  'town',
#  'thought',
#  'large',
#  'order',
#  'drills',
#  'hoping',
#  'day',
#  'edge',
#  'town',
#  'drills',
#  'driven',
#  'mind',
#  'sat',
#  'usual',
#  'morning',
#  'traffic',
#  'jam',
#  'help',
#  'noticing',
#  'lot',
#  'strangely',
#  'dressed',
#  'people',
#  'people',
#  'cloaks',
#  'mr',
#  'dursley',
#  'bear',
#  'people',
#  'dressed',
#  'funny',
#  'clothes',
#  'getups',
#  'saw',
#  'young',
#  'people',
#  'supposed',
#  'stupid',
#  'new',
#  'fashion',
#  'drummed',
#  'fingers',
#  'steering',
#  'wheel',
#  'eyes',
#  'fell',
#  'huddle',
#  'weirdos',
#  'standing',
#  'quite',
#  'close',
#  'whispering',
#  'excitedly',
#  'mr',
#  'dursley',
#  'enraged',
#  'couple',
#  'werent',
#  'young',
#  'man',
#  'older',
#  'wearing',
#  'emeraldgreen',
#  'cloak',
#  'nerve',
#  'struck',
#  'mr',
#  'dursley',
#  'probably',
#  'silly',
#  'stunt',
#  'people',
#  'obviously',
#  'collecting',
#  'yes',
#  'traffic',
#  'moved',
#  'minutes',
#  'later',
#  'mr',
#  'dursley',
#  'arrived',
#  'grunnings',
#  'parking',
#  'lot',
#  'mind',
#  'drills',
#  'mr',
#  'dursley',
#  'sat',
#  'window',
#  'office',
#  'ninth',
#  'floor',
#  'hadnt',
#  'harder',
#  'concentrate',
#  'drills',
#  'morning',
#  'didnt',
#  'owls',
#  'swooping',
#  'past',
#  'broad',
#  'daylight',
#  'people',
#  'street',
#  'did',
#  'pointed',
#  'gazed',
#  'open',
#  'mouthed',
#  'owl',
#  'owl',
#  'sped',
#  'overhead',
#  'seen',
#  'owl',
#  'nighttime',
#  'mr',
#  'dursley',
#  'perfectly',
#  'normal',
#  'owlfree',
#  'morning',
#  'yelled',
#  'different',
#  'people',
#  'important',
#  'telephone',
#  'calls',
#  'shouted',
#  'bit',
#  'good',
#  'mood',
#  'lunchtime',
#  'thought',
#  'hed',
#  'stretch',
#  'legs',
#  'walk',
#  'road',
#  'buy',
#  'himself',
#  'bun',
#  'bakery',
#  'hed',
#  'forgotten',
#  'people',
#  'cloaks',
#  'passed',
#  'group',
#  'bakers',
#  'eyed',
#  'angrily',
#  'passed',
#  'didnt',
#  'know',
#  'uneasy',
#  'bunch',
#  'whispering',
#  'excitedly',
#  'single',
#  'collecting',
#  'tin',
#  'way',
#  'past',
#  'clutching',
#  'large',
#  'doughnut',
#  'bag',
#  'caught',
#  'words',
#  'saying',
#  'potters',
#  'thats',
#  'right',
#  'thats',
#  'heard',
#  'yes',
#  'son',
#  'harry',
#  'mr',
#  'dursley',
#  'stopped',
#  'dead',
#  'fear',
#  'flooded',
#  'looked',
#  'whisperers',
#  'wanted',
#  'say',
#  'thought',
#  'better',
#  'dashed',
#  'road',
#  'hurried',
#  'office',
#  'snapped',
#  'secretary',
#  'disturb',
#  'seized',
#  'telephone',
#  'finished',
#  'dialing',
#  'home',
#  'number',
#  'changed',
#  'mind',
#  'receiver',
#  'stroked',
#  'mustache',
#  'thinking',
#  'stupid',
#  'potter',
#  'wasnât',
#  'unusual',
#  'sure',
#  'lots',
#  'people',
#  'called',
#  'potter',
#  'son',
#  'called',
#  'harry',
#  'come',
#  'think',
#  'wasnât',
#  'sure',
#  'nephew',
#  'called',
#  'harry',
#  'heâd',
#  'seen',
#  'boy',
#  'harvey',
#  'harold',
#  'point',
#  'worrying',
#  'mrs',
#  'dursley',
#  'got',
#  'upset',
#  'mention',
#  'sister',
#  'didnât',
#  'blame',
#  'â',
#  'heâd',
#  'sister',
#  'like',
#  'people',
#  'cloaks',
#  'lot',
#  'harder',
#  'concentrate',
#  'drills',
#  'afternoon',
#  'left',
#  'building',
#  'oâclock',
#  'worried',
#  'walked',
#  'straight',
#  'just',
#  'outside',
#  'door',
#  'sorry',
#  'grunted',
#  'tiny',
#  'old',
#  'man',
#  'stumbled',
#  'fell',
#  'seconds',
#  'mr',
#  'dursley',
#  'realized',
#  'man',
#  'wearing',
#  'violet',
#  'cloak',
#  'didnt',
#  'upset',
#  'knocked',
#  'ground',
#  'contrary',
#  'face',
#  'split',
#  'wide',
#  'smile',
#  'said',
#  'squeaky',
#  'voice',
#  'passersby',
#  'stare',
#  'dont',
#  'sorry',
#  'dear',
#  'sir',
#  'upset',
#  'today',
#  'rejoice',
#  'youknowwho',
#  'gone',
#  'muggles',
#  'like',
#  'celebrating',
#  'happy',
#  'happy',
#  'day',
#  'old',
#  'man',
#  'hugged',
#  'mr',
#  'dursley',
#  'middle',
#  'walked',
#  'mr',
#  'dursley',
#  'stood',
#  'rooted',
#  'spot',
#  'hugged',
#  'complete',
#  'stranger',
#  'thought',
#  'called',
#  'muggle',
#  'rattled',
#  'hurried',
#  'car',
#  'set',
#  'home',
#  'hoping',
#  'imagining',
#  'things',
#  'hoped',
#  'didnt',
#  'approve',
#  'imagination',
#  'pulled',
#  'driveway',
#  'number',
#  'thing',
#  'saw',
#  'didnt',
#  'improve',
#  'mood',
#  'tabby',
#  'cat',
#  'hed',
#  'spotted',
#  'morning',
#  'sitting',
#  'garden',
#  'wall',
#  'sure',
#  'markings',
#  'eyes',
#  'shoo',
#  'said',
#  'mr',
#  'dursley',
#  'loudly',
#  'cat',
#  'didnt',
#  'just',
#  'gave',
#  'stern',
#  'look',
#  'normal',
#  'cat',
#  'behavior',
#  'mr',
#  'dursley',
#  'wondered',
#  'trying',
#  'pull',
#  'himself',
#  'let',
#  'himself',
#  'house',
#  'determined',
#  'mention',
#  'wife',
#  'mrs',
#  'dursley',
#  'nice',
#  'normal',
#  'day',
#  'told',
#  'dinner',
#  'mrs',
#  'doors',
#  'problems',
#  'daughter',
#  'dudley',
#  'learned',
#  'new',
#  'word',
#  'wont',
#  'mr',
#  'dursley',
#  'tried',
#  'act',
#  'normally',
#  'dudley',
#  'bed',
#  'went',
#  'living',
#  'room',
#  'time',
#  'catch',
#  'report',
#  'evening',
#  'news',
#  'finally',
#  'birdwatchers',
#  'reported',
#  'nations',
#  'owls',
#  'behaving',
#  'unusually',
#  'today',
#  'owls',
#  'normally',
#  'hunt',
#  'night',
#  'hardly',
#  'seen',
#  'daylight',
#  'hundreds',
#  'sightings',
#  'birds',
#  'flying',
#  'direction',
#  'sunrise',
#  'experts',
#  'unable',
#  'explain',
#  'owls',
#  'suddenly',
#  'changed',
#  'sleeping',
#  'pattern',
#  'newscaster',
#  'allowed',
#  'himself',
#  'grin',
#  'mysterious',
#  'jim',
#  'mcguffin',
#  'weather',
#  'going',
#  'showers',
#  'owls',
#  'tonight',
#  'jim',
#  'ted',
#  'said',
#  'weatherman',
#  'dont',
#  'know',
#  'owls',
#  'acting',
#  'oddly',
#  'today',
#  'viewers',
#  'far',
#  'apart',
#  'kent',
#  'yorkshire',
#  'dundee',
#  'phoning',
#  'tell',
#  'instead',
#  'rain',
#  'promised',
#  'yesterday',
#  'theyve',
#  'downpour',
#  'shooting',
#  'stars',
#  'people',
#  'celebrating',
#  'bonfire',
#  'night',
#  'early',
#  'week',
#  'folks',
#  'promise',
#  'wet',
#  'night',
#  'tonight',
#  'mr',
#  'dursley',
#  'sat',
#  'frozen',
#  'armchair',
#  'shooting',
#  'stars',
#  'britain',
#  'owls',
#  'flying',
#  'daylight',
#  'mysterious',
#  'people',
#  'cloaks',
#  'place',
#  'whisper',
#  'whisper',
#  'potters',
#  'mrs',
#  'dursley',
#  'came',
#  'living',
#  'room',
#  'carrying',
#  'cups',
#  'tea',
#  'good',
#  'hed',
#  'say',
#  'cleared',
#  'throat',
#  'nervously',
#  'er',
#  'petunia',
#  'dear',
#  'havent',
#  'heard',
#  'sister',
#  'lately',
#  'expected',
#  'mrs',
#  'dursley',
#  'looked',
#  'shocked',
#  'angry',
#  'normally',
#  'pretended',
#  'didnt',
#  'sister',
#  'said',
#  'sharply',
#  'funny',
#  'stuff',
#  'news',
#  'mr',
#  'dursley',
#  'mumbled',
#  'owls',
#  'shooting',
#  'stars',
#  'lot',
#  'funnylooking',
#  'people',
#  'town',
#  'today',
#  'snapped',
#  'mrs',
#  'dursley',
#  'just',
#  'thought',
#  'maybe',
#  'know',
#  'crowd',
#  'mrs',
#  'dursley',
#  'sipped',
#  'tea',
#  'pursed',
#  'lips',
#  'mr',
#  'dursley',
#  'wondered',
#  'dared',
#  'tell',
#  'hed',
#  'heard',
#  'potter',
#  'decided',
#  'didnt',
#  'dare',
#  'instead',
#  'said',
#  'casually',
#  'son',
#  'hed',
#  'dudleys',
#  'age',
#  'wouldnt',
#  'suppose',
#  'said',
#  'mrs',
#  'dursley',
#  'stiffly',
#  'whats',
#  'howard',
#  'isnt',
#  'harry',
#  'nasty',
#  'common',
#  'ask',
#  'oh',
#  'yes',
#  'said',
#  'mr',
#  'dursley',
#  'heart',
#  'sinking',
#  'horribly',
#  'yes',
#  'quite',
#  'agree',
#  'didnt',
#  'say',
#  'word',
#  'subject',
#  'went',
#  'upstairs',
#  'bed',
#  'mrs',
#  'dursley',
#  'bathroom',
#  'mr',
#  'dursley',
#  'crept',
#  'bedroom',
#  'window',
#  'peered',
#  'garden',
#  'cat',
#  'staring',
#  'privet',
#  'drive',
#  'waiting',
#  'imagining',
#  'things',
#  'potters',
#  'did',
#  'got',
#  'related',
#  'pair',
#  'didnt',
#  'think',
#  'bear',
#  'dursleys',
#  'got',
#  'bed',
#  'mrs',
#  'dursley',
#  'fell',
#  'asleep',
#  'quickly',
#  'mr',
#  'dursley',
#  'lay',
#  'awake',
#  'turning',
#  'mind',
#  'comforting',
#  'thought',
#  'fell',
#  'asleep',
#  'potters',
#  'involved',
#  'reason',
#  'come',
#  'near',
#  'mrs',
#  'dursley',
#  'potters',
#  'knew',
#  'petunia',
#  'thought',
#  'kind',
#  'couldnât',
#  'petunia',
#  'mixed',
#  'going',
#  'â',
#  'yawned',
#  'turned',
#  'â',
#  'couldnât',
#  'affect',
#  'wrong',
#  'mr',
#  'dursley',
#  'drifting',
#  'uneasy',
#  'sleep',
#  'cat',
#  'wall',
#  'outside',
#  'showing',
#  'sign',
#  'sleepiness',
#  'sitting',
#  'statue',
#  'eyes',
#  'fixed',
#  'unblinkingly',
#  'far',
#  'corner',
#  'privet',
#  'drive',
#  'didnât',
#  'quiver',
#  'car',
#  'door',
#  'slammed',
#  'street',
#  'owls',
#  'swooped',
#  'overhead',
#  'fact',
#  'nearly',
#  'midnight',
#  'cat',
#  'moved',
#  'man',
#  'appeared',
#  'corner',
#  'cat',
#  'watching',
#  'appeared',
#  'suddenly',
#  'silently',
#  'youd',
#  'thought',
#  'hed',
#  'just',
#  'popped',
#  'ground',
#  'cats',
#  'tail',
#  'twitched',
#  'eyes',
#  'narrowed',
#  ...]

# %% [markdown]
# Generators

# %%
# this is just a proof of concept on how generators work
def num_gen():
    for i in range(5):
        yield i
        
gen = num_gen()

# %%
next(gen)
# Out:
# 0

# %%
for i in gen:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
# this next command will fail after running the previous 3 cells since the generator is exhausted
next(gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-5-09970eb06ab0> in <module>()
#       1 # this next command will fail after running the previous 3 cells since the generator is exhausted
# ----> 2 next(gen)
#
# StopIteration:

# %% [markdown]
# Now let's do a direct comparison between a list and generator.

# %%
import calendar
# list
def leap_years_list(n=1000000):
    leap_years = []
    for year in range(1, n+1):
        if calendar.isleapyear(year):
            leap_years.append(year)
    return leap_years

# generators
def leap_years_gen(n=1000000):
    for year in range(1, n+1):
        if calendar.isleapyear(year):
            yield year

# %%
# %timeit -n1 leap_years_list()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-fbc146b8b06f> in <module>()
# ----> 1 get_ipython().run_line_magic('timeit', '-n1 leap_years_list()')
#
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2093                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2094             with self.builtin_trap:
# -> 2095                 result = fn(*args,**kwargs)
#    2096             return result
#    2097
#
# <decorator-gen-61> in timeit(self, line, cell, local_ns)
#
# /anaconda3/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /anaconda3/lib/python3.6/site-packages/IPython/core/magics/execution.py in timeit(self, line, cell, local_ns)
#    1100                     break
#    1101
# -> 1102         all_runs = timer.repeat(repeat, number)
#    1103         best = min(all_runs) / number
#    1104         worst = max(all_runs) / number
#
# /anaconda3/lib/python3.6/timeit.py in repeat(self, repeat, number)
#     204         r = []
#     205         for i in range(repeat):
# --> 206             t = self.timeit(number)
#     207             r.append(t)
#     208         return r
#
# /anaconda3/lib/python3.6/site-packages/IPython/core/magics/execution.py in timeit(self, number)
#     158         gc.disable()
#     159         try:
# --> 160             timing = self.inner(it, self.timer)
#     161         finally:
#     162             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# <ipython-input-1-48ee97cf725d> in leap_years_list(n)
#       3     leap_years = []
#       4     for year in range(1, n+1):
# ----> 5         if calendar.isleapyear(year):
#       6             leap_years.append(year)
#       7     return leap_years
#
# NameError: name 'calendar' is not defined
